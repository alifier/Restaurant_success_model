# %% [markdown]
# # Join Old and New Datasets
#
# In this notebook we show the code used to merge the old and new Yelp datasets. The old dataset is provided by Kaggle. From this dataset we have only kept the data about restaurants and more specifically those restaurants that were still open when the dataset was collected. The new dataset was pulled from the Yelp Business API and it contains the most recent information for the same restaurants (with some minor mistakes that we will try to find by matching the old and new information).
#
# We have already tried merging the old dataset with the information pulled from the Yelp Search API but a lot of this information was not matched because Yelp does not always return results for restaurants that closed a long time ago. In addition some restaurants rebranded or moved.
#
# The restaurants that did not match in name and address with our initial effort are contained in the *restaurants_new_notmerged* dataframe and are marked as "found: 0" in the *restaurants_old* dataframe.

# %%
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Now we will read the 2 dataframes containing the new data pulled from the Yelp Business API. One of these dataframes was already merged successfully with the old data and the other one was not. Both datasets contain more information that the Yelp Search API provides and for this we will merge them again and will ignore the information from the Yelp Search API.

# %%
# Read the 2 dataframes with the new dataset pulled from the Yelp Business API
restaurants_new_notmerged = pd.read_pickle('./yelp_dataset_processed/yelp_df_notmerged_new.pkl')
restaurants_new_merged = pd.read_pickle('./yelp_dataset_processed/yelp_df_merged_new.pkl')

# Read the dataframe with the old Yelp dataset marked as found (1 for merged, 0 for notmerged)
#restaurants_old = pd.read_pickle('./yelp_old/yelp_training_set/yelp_training_open_restaurants.pkl')
restaurants_old = pd.read_pickle('./yelp_dataset_processed/yelp_df_found.pkl')

# %% [markdown]
# Let's take a look at the data

# %%
# Dataframe with new info from restaurants that did not match in name and address in our initial effort
restaurants_new_notmerged.head()
# Out:
#                                           categories  coordinates.latitude  \
# 0         [{'alias': 'mexican', 'title': 'Mexican'}]             33.480195
# 1         [{'alias': 'mexican', 'title': 'Mexican'}]             32.945603
# 2             [{'alias': 'delis', 'title': 'Delis'}]             33.423805
# 3         [{'alias': 'chinese', 'title': 'Chinese'}]             33.568398
# 4  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...             33.504062
#
#    coordinates.longitude   display_phone error.code error.description  \
# 0            -112.081313  (602) 266-1423        NaN               NaN
# 1            -112.725909  (928) 683-6382        NaN               NaN
# 2            -111.735786  (480) 641-4170        NaN               NaN
# 3            -112.100121  (602) 678-4293        NaN               NaN
# 4            -111.929431  (480) 945-1928        NaN               NaN
#
#                                                hours  \
# 0  [{'open': [{'is_overnight': False, 'start': '0...
# 1  [{'open': [{'is_overnight': False, 'start': '0...
# 2  [{'open': [{'is_overnight': False, 'start': '0...
# 3  [{'open': [{'is_overnight': False, 'start': '1...
# 4  [{'open': [{'is_overnight': False, 'start': '1...
#
#                                id  \
# 0  la-paloma-mexican-food-phoenix
# 1   sofias-mexican-food-gila-bend
# 2                   yee-haws-mesa
# 3           panda-gourmet-phoenix
# 4          five-guys-scottsdale-2
#
#                                            image_url is_claimed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/qUjY7x...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/WddzkO...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/5HfVEs...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/eIsbpn...       True
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/xjJkzA...       True
#
#                          ...                         location.state  \
# 0                        ...                                     AZ
# 1                        ...                                     AZ
# 2                        ...                                     AZ
# 3                        ...                                     AZ
# 4                        ...                                     AZ
#
#   location.zip_code                    name         phone  \
# 0             85013  La Paloma Mexican Food  +16022661423
# 1             85337    Sofia's Mexican Food  +19286836382
# 2             85205                Yee-haws  +14806414170
# 3             85021           Panda Gourmet  +16026784293
# 4             85251               Five Guys  +14809451928
#
#                                               photos price rating  \
# 0  [https://s3-media2.fl.yelpcdn.com/bphoto/qUjY7...     $    3.0
# 1  [https://s3-media2.fl.yelpcdn.com/bphoto/Wddzk...     $    4.0
# 2  [https://s3-media2.fl.yelpcdn.com/bphoto/5HfVE...     $    4.5
# 3  [https://s3-media3.fl.yelpcdn.com/bphoto/eIsbp...   NaN    3.5
# 4  [https://s3-media2.fl.yelpcdn.com/bphoto/xjJkz...    $$    3.5
#
#   review_count transactions                                                url
# 0         18.0           []  https://www.yelp.com/biz/la-paloma-mexican-foo...
# 1         86.0           []  https://www.yelp.com/biz/sofias-mexican-food-g...
# 2          3.0           []  https://www.yelp.com/biz/yee-haws-mesa?adjust_...
# 3          5.0           []  https://www.yelp.com/biz/panda-gourmet-phoenix...
# 4         87.0           []  https://www.yelp.com/biz/five-guys-scottsdale-...
#
# [5 rows x 28 columns]

# %%
# Dataframe with new info from restaurants that matched in name and address in our initial effort 
# (and therefore business id was known)
restaurants_new_merged.head()
# Out:
#                                           categories  coordinates.latitude  \
# 0  [{'alias': 'bagels', 'title': 'Bagels'}, {'ali...             33.713596
# 1  [{'alias': 'sandwiches', 'title': 'Sandwiches'...             33.378695
# 2  [{'alias': 'italian', 'title': 'Italian'}, {'a...             33.617460
# 3  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...             33.566990
# 4  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...             33.581867
#
#    coordinates.longitude   display_phone  \
# 0            -112.200125  (623) 825-0355
# 1            -111.812692  (480) 632-6453
# 2            -111.926260  (480) 321-8800
# 3            -112.116241  (602) 870-1111
# 4            -111.881622  (480) 451-1803
#
#                                                hours  \
# 0  [{'open': [{'is_overnight': False, 'start': '0...
# 1  [{'open': [{'is_overnight': False, 'start': '1...
# 2  [{'open': [{'is_overnight': False, 'start': '1...
# 3                                                NaN
# 4                                                NaN
#
#                                   id  \
# 0    hot-bagels-and-deli-glendale-az
# 1        jersey-mikes-subs-gilbert-2
# 2  sauce-pizza-and-wine-scottsdale-2
# 3              fuddruckers-phoenix-3
# 4             mcdonalds-scottsdale-5
#
#                                            image_url  is_claimed  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/efZ-8J...        True      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/BYIdRj...        True      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/1lTHQh...        True      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/gcmpOL...        True      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/ofHjsT...       False      False
#
#              location.address1  \
# 0       6520 W Happy Valley Rd
# 1            891 E Baseline Rd
# 2        14418 N Scottsdale Rd
# 3  8941 North Black Canyon Hwy
# 4             9251 E Shea Blvd
#
#                          ...                         location.state  \
# 0                        ...                                     AZ
# 1                        ...                                     AZ
# 2                        ...                                     AZ
# 3                        ...                                     AZ
# 4                        ...                                     AZ
#
#   location.zip_code                  name         phone  \
# 0             85310     Hot Bagels & Deli  +16238250355
# 1             85233    Jersey Mike's Subs  +14806326453
# 2             85254  Sauce Pizza and Wine  +14803218800
# 3             85021           Fuddruckers  +16028701111
# 4             85258            McDonald's  +14804511803
#
#                                               photos price rating  \
# 0  [https://s3-media4.fl.yelpcdn.com/bphoto/efZ-8...     $    3.5
# 1  [https://s3-media2.fl.yelpcdn.com/bphoto/eTDf8...     $    3.0
# 2  [https://s3-media2.fl.yelpcdn.com/bphoto/1lTHQ...    $$    3.5
# 3  [https://s3-media4.fl.yelpcdn.com/bphoto/gcmpO...    $$    3.5
# 4  [https://s3-media4.fl.yelpcdn.com/bphoto/ofHjs...     $    2.5
#
#   review_count transactions                                                url
# 0           77           []  https://www.yelp.com/biz/hot-bagels-and-deli-g...
# 1           29     [pickup]  https://www.yelp.com/biz/jersey-mikes-subs-gil...
# 2          163     [pickup]  https://www.yelp.com/biz/sauce-pizza-and-wine-...
# 3           81           []  https://www.yelp.com/biz/fuddruckers-phoenix-3...
# 4           16           []  https://www.yelp.com/biz/mcdonalds-scottsdale-...
#
# [5 rows x 26 columns]

# %%
# Dataframe with old info (Kaggle dataset)
restaurants_old.head()
# Out:
#               business_id                          categories        city  \
# 0  PzOqRohWw7F7YEPBz6AubA  [Food, Bagels, Delis, Restaurants]    Glendale
# 1  qarobAbxGSHI7ygf1f7a_Q           [Sandwiches, Restaurants]     Gilbert
# 2  gA5CuBxF-0CnOpGnryWJdQ              [Mexican, Restaurants]     Phoenix
# 3  JxVGJ9Nly2FFIs_WpJvkug                [Pizza, Restaurants]  Scottsdale
# 4  Jj7bcQ6NDfKoz4TXwvYfMg              [Burgers, Restaurants]     Phoenix
#
#                                         full_address   latitude   longitude  \
# 0  6520 W Happy Valley Rd\nSte 101\nGlendale Az, ...  33.712797 -112.200264
# 1    891 E Baseline Rd\nSuite 102\nGilbert, AZ 85233  33.378839 -111.812007
# 2                 519 W Thomas Rd\nPhoenix, AZ 85013  33.480105 -112.081361
# 3  14418 N Scottsdale Rd\nSuite 181\nScottsdale, ...  33.617459 -111.926272
# 4         8941 N Black Canyon Hwy\nPhoenix, AZ 85021  33.566989 -112.116243
#
#                      name neighborhoods  open  review_count  stars state  \
# 0       Hot Bagels & Deli            []  True            14    3.5    AZ
# 1      Jersey Mike's Subs            []  True            10    3.5    AZ
# 2  La Paloma Mexican Food            []  True             5    4.0    AZ
# 3                   Sauce            []  True            55    4.0    AZ
# 4             Fuddruckers            []  True            23    4.0    AZ
#
#        type  found
# 0  business      1
# 1  business      1
# 2  business      0
# 3  business      1
# 4  business      1

# %% [markdown]
# Now we will check if the old dataset contains the same number of rows as the old and new datasets. The entries for not found (*found=0*) restaurants should match the entries of the *notmerged* dataframe while the entries of the found restaurants (*found=1*) should match the entries of the *merged* dataframe.

# %%
# Check if length of dataframes is the same
len(restaurants_old[restaurants_old['found'] == 0]) == len(restaurants_new_notmerged)
# Out:
# True

# %%
len(restaurants_old[restaurants_old['found'] == 1]) == len(restaurants_new_merged)
# Out:
# True

# %% [markdown]
# Here, we will try to match the names from the old and new datasets that were notmerged with our previous effort. If the first 4 consecutive letters of the name from the old or new dataset is found in the other one, then the names match. If the first 4 consecutive letters of the old address match the 4 first consecutive letters of the others of the new address then the addresses match.
#
# If none of the address or name match then we throw out that datapoint and mark old entry as "not found".
#
# If a name matches but the address doesn't, then mark as closed if new location closed, else throw out and mark old entry as "not found".
#
# If an address matches but the name doesn't, then throw out and mark old entry as "not found".

# %%
# A dictionary of names that remained similar. These are used as an equivalency criterion when tables are merged
changed_names = {'O.H.S.O. Eatery + nanoBrewery':'OHSO Brewery- Arcadia',
                'Kentucky Fried Chicken':'KFC',
                 'Kfc': 'KFC',
                'Pancho Taqueria':'Taqueria Don Pancho',
                'International House of Pancakes':'IHOP',
                "PF Chang's China Bistro": "P.F. Chang's",
                "Aj's Cafe": "AJ's",
                'AZ 88':'AZ88',
                'Azteca Bakery & Mexican Fast Food': 'AZTECA Bakeries & Restaurant',
                'Losbetos Mexican Food': 'Los Betos Mexican Food',
                'U.S. Egg': 'US Egg Restaurant',
                'Mr Hunan': 'Mr. Hunan',
                'NCounter': 'Ncounter',
                'The Café at MIM': 'Musical Instrument Museum',
                 'Lox Stock & Bagel': 'Lox, Stock & Bagel',
                 'Kiku Sushi': 'KiKu Revolving Sushi',
                 'Caffe Sarajevo': 'Old Town Sarajevo',
                 "YC'S Mongolian Grill": "YC's Mongolian Grill",
                 "Harvest Buffet": "The Buffet"
                }

# %%
restaurants_all_notmerged = pd.DataFrame()

restaurants_old_notfound = restaurants_old[restaurants_old['found'] == 0].reset_index() # old index will become a new column
restaurants_old['found2'] = 0

# make sure address starts the same and names are similar
for i, restaurant in restaurants_new_notmerged.iterrows():

    if restaurants_old_notfound.loc[i]["name"] in changed_names:
        # if name has changed, take dictionary into account
        if restaurant['location.address1'][:4] == restaurants_old_notfound.loc[i].full_address[:4] and \
        ((restaurant["name"][:4] in restaurants_old_notfound.loc[i]["name"]) or (restaurants_old_notfound.loc[i]["name"][:4] in restaurant["name"])\
        or changed_names[restaurants_old_notfound.loc[i]["name"]] == restaurant["name"]):
            restaurants_old.loc[restaurants_old_notfound.loc[i,'index'],'found2'] = 1
            restaurants_all_notmerged = \
            restaurants_all_notmerged.append(restaurant.to_frame().T.reset_index(drop = True).join(restaurants_old_notfound.loc[i].to_frame().T.reset_index(drop = True),lsuffix='_new'),ignore_index=True)

    else:
        # if name not in dict, just check address and name similarity
        if restaurant['error.code'] != 'BUSINESS_UNAVAILABLE':
            if (restaurant['location.address1'] is not None):
            # If not a foodtruck
                if restaurant['location.address1'][:4] == restaurants_old_notfound.loc[i].full_address[:4] and \
                ((restaurant["name"][:4] in restaurants_old_notfound.loc[i]["name"]) or (restaurants_old_notfound.loc[i]["name"][:4] in restaurant["name"])):
                    restaurants_old.loc[restaurants_old_notfound.loc[i,'index'],'found2'] = 1
                    restaurants_all_notmerged = \
                    restaurants_all_notmerged.append(restaurant.to_frame().T.reset_index(drop = True).join(restaurants_old_notfound.loc[i].to_frame().T.reset_index(drop = True),lsuffix='_new'),ignore_index=True)
            else:
                # if a foodtruck (no address)
                if ((restaurant["name"][:4] in restaurants_old_notfound.loc[i]["name"]) or (restaurants_old_notfound.loc[i]["name"][:4] in restaurant["name"])):
                    restaurants_old.loc[restaurants_old_notfound.loc[i,'index'],'found2'] = 1
                    restaurants_all_notmerged = \
                    restaurants_all_notmerged.append(restaurant.to_frame().T.reset_index(drop = True).join(restaurants_old_notfound.loc[i].to_frame().T.reset_index(drop = True),lsuffix='_new'),ignore_index=True)

# %% [markdown]
# Check if merging was done correctly by looking at the data and the number of lines.

# %%
restaurants_all_notmerged.head()
# Out:
#                                       categories_new coordinates.latitude  \
# 0         [{'alias': 'mexican', 'title': 'Mexican'}]              33.4802
# 1             [{'alias': 'delis', 'title': 'Delis'}]              33.4238
# 2         [{'alias': 'chinese', 'title': 'Chinese'}]              33.5684
# 3  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...              33.5041
# 4  [{'alias': 'sandwiches', 'title': 'Sandwiches'...              33.3356
#
#   coordinates.longitude   display_phone error.code error.description  \
# 0              -112.081  (602) 266-1423        NaN               NaN
# 1              -111.736  (480) 641-4170        NaN               NaN
# 2                -112.1  (602) 678-4293        NaN               NaN
# 3              -111.929  (480) 945-1928        NaN               NaN
# 4              -111.963  (480) 763-1776        NaN               NaN
#
#                                                hours  \
# 0  [{'open': [{'is_overnight': False, 'start': '0...
# 1  [{'open': [{'is_overnight': False, 'start': '0...
# 2  [{'open': [{'is_overnight': False, 'start': '1...
# 3  [{'open': [{'is_overnight': False, 'start': '1...
# 4  [{'open': [{'is_overnight': False, 'start': '1...
#
#                                                  id  \
# 0                    la-paloma-mexican-food-phoenix
# 1                                     yee-haws-mesa
# 2                             panda-gourmet-phoenix
# 3                            five-guys-scottsdale-2
# 4  forefathers-gourmet-cheesesteaks-and-fries-tempe
#
#                                            image_url is_claimed  ...   \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/qUjY7x...      False  ...
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/5HfVEs...      False  ...
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/eIsbpn...       True  ...
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/xjJkzA...       True  ...
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/4VKNBZ...       True  ...
#
#   latitude longitude                                      name neighborhoods  \
# 0  33.4801  -112.081                    La Paloma Mexican Food            []
# 1  33.4238  -111.736                                  Yee-haws            []
# 2  33.5683    -112.1                             Panda Gourmet            []
# 3  33.5033  -111.928                Five Guys Burger and Fries            []
# 4  33.3352  -111.963  Forefathers Gourmet Cheesesteaks & Fries            []
#
#    open review_count stars state      type found
# 0  True            5     4    AZ  business     0
# 1  True            3   3.5    AZ  business     0
# 2  True            3   3.5    AZ  business     0
# 3  True           52   3.5    AZ  business     0
# 4  True          106     4    AZ  business     0
#
# [5 rows x 43 columns]

# %%
len(restaurants_old[restaurants_old['found2'] == 1]) == len(restaurants_all_notmerged)
# Out:
# True

# %%
len(restaurants_all_notmerged)
# Out:
# 930

# %%
# Percentage of closed restaurants within the merged list that were not merged initially
len(restaurants_all_notmerged[restaurants_all_notmerged['is_closed']==1])/len(restaurants_all_notmerged)
# Out:
# 0.6827956989247311

# %% [markdown]
# Repeat the same process to merge the information from the restaurants that were already merged in our previous effort (with info from the Yelp Search API). The Yelp Business API contains more info and therefore can be utilized better.

# %%
restaurants_all_merged = pd.DataFrame()

restaurants_old_found = restaurants_old[restaurants_old['found'] == 1].reset_index() # old index will become a new column

# make sure address starts the same and names are similar
for i, restaurant in restaurants_new_merged.iterrows():

    if restaurants_old_found.loc[i]["name"] in changed_names:
        # if name has changed, take dictionary into account
        if restaurant['location.address1'][:4] == restaurants_old_found.loc[i].full_address[:4] and \
        ((restaurant["name"][:4] in restaurants_old_found.loc[i]["name"]) or (restaurants_old_found.loc[i]["name"][:4] in restaurant["name"])\
        or (changed_names[restaurants_old_found.loc[i]["name"]] in restaurant["name"]) or (restaurant["name"] in changed_names[restaurants_old_found.loc[i]["name"]])):
            restaurants_old.loc[restaurants_old_found.loc[i,'index'],'found2'] = 1
            restaurants_all_merged = \
            restaurants_all_merged.append(restaurant.to_frame().T.reset_index(drop = True).join(restaurants_old_found.loc[i].to_frame().T.reset_index(drop = True),lsuffix='_new'),ignore_index=True)

    else:
        # if name not in dict, just check address and name similarity
        if (restaurant['location.address1'] is not None):
        # If not a foodtruck
            if restaurant['location.address1'][:4] == restaurants_old_found.loc[i].full_address[:4] and \
            ((restaurant["name"][:4] in restaurants_old_found.loc[i]["name"]) or (restaurants_old_found.loc[i]["name"][:4] in restaurant["name"])):
                restaurants_old.loc[restaurants_old_found.loc[i,'index'],'found2'] = 1
                restaurants_all_merged = \
                restaurants_all_merged.append(restaurant.to_frame().T.reset_index(drop = True).join(restaurants_old_found.loc[i].to_frame().T.reset_index(drop = True),lsuffix='_new'),ignore_index=True)
        else:
            # if a foodtruck (no address)
            if ((restaurant["name"][:4] in restaurants_old_found.loc[i]["name"]) or (restaurants_old_found.loc[i]["name"][:4] in restaurant["name"])):
                restaurants_old.loc[restaurants_old_found.loc[i,'index'],'found2'] = 1
                restaurants_all_merged = \
                restaurants_all_merged.append(restaurant.to_frame().T.reset_index(drop = True).join(restaurants_old_found.loc[i].to_frame().T.reset_index(drop = True),lsuffix='_new'),ignore_index=True)

# %%
restaurants_all_merged.head()
# Out:
#                                       categories_new coordinates.latitude  \
# 0  [{'alias': 'bagels', 'title': 'Bagels'}, {'ali...              33.7136
# 1  [{'alias': 'sandwiches', 'title': 'Sandwiches'...              33.3787
# 2  [{'alias': 'italian', 'title': 'Italian'}, {'a...              33.6175
# 3  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...               33.567
# 4  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...              33.5819
#
#   coordinates.longitude   display_phone  \
# 0                -112.2  (623) 825-0355
# 1              -111.813  (480) 632-6453
# 2              -111.926  (480) 321-8800
# 3              -112.116  (602) 870-1111
# 4              -111.882  (480) 451-1803
#
#                                                hours  \
# 0  [{'open': [{'is_overnight': False, 'start': '0...
# 1  [{'open': [{'is_overnight': False, 'start': '1...
# 2  [{'open': [{'is_overnight': False, 'start': '1...
# 3                                                NaN
# 4                                                NaN
#
#                                   id  \
# 0    hot-bagels-and-deli-glendale-az
# 1        jersey-mikes-subs-gilbert-2
# 2  sauce-pizza-and-wine-scottsdale-2
# 3              fuddruckers-phoenix-3
# 4             mcdonalds-scottsdale-5
#
#                                            image_url is_claimed is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/efZ-8J...       True     False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/BYIdRj...       True     False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/1lTHQh...       True     False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/gcmpOL...       True     False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/ofHjsT...      False     False
#
#              location.address1  ...   longitude                name  \
# 0       6520 W Happy Valley Rd  ...      -112.2   Hot Bagels & Deli
# 1            891 E Baseline Rd  ...    -111.812  Jersey Mike's Subs
# 2        14418 N Scottsdale Rd  ...    -111.926               Sauce
# 3  8941 North Black Canyon Hwy  ...    -112.116         Fuddruckers
# 4             9251 E Shea Blvd  ...    -111.882          McDonald's
#
#   neighborhoods  open review_count stars state      type found found2
# 0            []  True           14   3.5    AZ  business     1      1
# 1            []  True           10   3.5    AZ  business     1      1
# 2            []  True           55     4    AZ  business     1      1
# 3            []  True           23     4    AZ  business     1      1
# 4            []  True            3   2.5    AZ  business     1      1
#
# [5 rows x 42 columns]

# %%
len(restaurants_all_merged) == len(restaurants_old[restaurants_old['found'] == 1])
# Out:
# False

# %%
len(restaurants_all_merged)
# Out:
# 2397

# %%
len(restaurants_old[restaurants_old['found'] == 1])
# Out:
# 2398

# %%
# 2 restaurant that wes matched before wes not matched now
restaurants_old[(restaurants_old['found'] == 1) & (restaurants_old['found2'] == 0)]
# Out:
#                 business_id  \
# 803  jfXqQTdxktGQWkELGn-7wA
#
#                                             categories  city  \
# 803  [Food, Desserts, American (Traditional), Ameri...  Mesa
#
#                                           full_address   latitude  longitude  \
# 803  Superstition Springs Center\n6613 East Souther...  33.392319 -111.68773
#
#                        name neighborhoods  open  review_count  stars state  \
# 803  The Cheesecake Factory            []  True            35    3.5    AZ
#
#          type  found  found2
# 803  business      1       0

# %%
restaurants_old_found[(restaurants_old_found['index'] == 803)]
# Out:
#      index             business_id  \
# 509    803  jfXqQTdxktGQWkELGn-7wA
#
#                                             categories  city  \
# 509  [Food, Desserts, American (Traditional), Ameri...  Mesa
#
#                                           full_address   latitude  longitude  \
# 509  Superstition Springs Center\n6613 East Souther...  33.392319 -111.68773
#
#                        name neighborhoods  open  review_count  stars state  \
# 509  The Cheesecake Factory            []  True            35    3.5    AZ
#
#          type  found  found2
# 509  business      1       0

# %%
restaurants_new_merged.loc[509]
# Out:
# categories                  [{'alias': 'desserts', 'title': 'Desserts'}, {...
# coordinates.latitude                                                  33.3914
# coordinates.longitude                                                -111.689
# display_phone                                                  (480) 641-7300
# hours                       [{'open': [{'is_overnight': False, 'start': '1...
# id                                                the-cheesecake-factory-mesa
# image_url                   https://s3-media3.fl.yelpcdn.com/bphoto/xg3SZX...
# is_claimed                                                               True
# is_closed                                                               False
# location.address1                                         6613 E Southern Ave
# location.address2
# location.address3
# location.city                                                            Mesa
# location.country                                                           US
# location.cross_streets
# location.display_address                [6613 E Southern Ave, Mesa, AZ 85206]
# location.state                                                             AZ
# location.zip_code                                                       85206
# name                                                   The Cheesecake Factory
# phone                                                            +14806417300
# photos                      [https://s3-media3.fl.yelpcdn.com/bphoto/xg3SZ...
# price                                                                      $$
# rating                                                                    3.5
# review_count                                                              191
# transactions                                                               []
# url                         https://www.yelp.com/biz/the-cheesecake-factor...
# Name: 509, dtype: object

# %%
# Percentage of closed restaurants within the merged list that were not merged initially
len(restaurants_all_merged[restaurants_all_merged['is_closed']==1])/len(restaurants_all_merged)
# Out:
# 0.05590321234876929

# %%
restaurants_all = restaurants_all_merged.append(restaurants_all_notmerged.drop(['error.code','error.description'],axis=1),ignore_index=True)

# %%
restaurants_all.head()
# Out:
#               business_id                          categories  \
# 0  PzOqRohWw7F7YEPBz6AubA  [Food, Bagels, Delis, Restaurants]
# 1  qarobAbxGSHI7ygf1f7a_Q           [Sandwiches, Restaurants]
# 2  JxVGJ9Nly2FFIs_WpJvkug                [Pizza, Restaurants]
# 3  Jj7bcQ6NDfKoz4TXwvYfMg              [Burgers, Restaurants]
# 4  4IAzFJ159GEaIGX1-y6Bmw   [Burgers, Fast Food, Restaurants]
#
#                                       categories_new        city  \
# 0  [{'alias': 'bagels', 'title': 'Bagels'}, {'ali...    Glendale
# 1  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     Gilbert
# 2  [{'alias': 'italian', 'title': 'Italian'}, {'a...  Scottsdale
# 3  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     Phoenix
# 4  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...  Scottsdale
#
#   coordinates.latitude coordinates.longitude   display_phone found found2  \
# 0              33.7136                -112.2  (623) 825-0355     1      1
# 1              33.3787              -111.813  (480) 632-6453     1      1
# 2              33.6175              -111.926  (480) 321-8800     1      1
# 3               33.567              -112.116  (602) 870-1111     1      1
# 4              33.5819              -111.882  (480) 451-1803     1      1
#
#                                         full_address  \
# 0  6520 W Happy Valley Rd\nSte 101\nGlendale Az, ...
# 1    891 E Baseline Rd\nSuite 102\nGilbert, AZ 85233
# 2  14418 N Scottsdale Rd\nSuite 181\nScottsdale, ...
# 3         8941 N Black Canyon Hwy\nPhoenix, AZ 85021
# 4             9251 E Shea Blvd\nScottsdale, AZ 85258
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                               photos price rating  \
# 0  [https://s3-media4.fl.yelpcdn.com/bphoto/efZ-8...     $    3.5
# 1  [https://s3-media2.fl.yelpcdn.com/bphoto/eTDf8...     $      3
# 2  [https://s3-media2.fl.yelpcdn.com/bphoto/1lTHQ...    $$    3.5
# 3  [https://s3-media4.fl.yelpcdn.com/bphoto/gcmpO...    $$    3.5
# 4  [https://s3-media4.fl.yelpcdn.com/bphoto/ofHjs...     $    2.5
#
#   review_count review_count_new stars state transactions      type  \
# 0           14               77   3.5    AZ           []  business
# 1           10               29   3.5    AZ     [pickup]  business
# 2           55              163     4    AZ     [pickup]  business
# 3           23               81     4    AZ           []  business
# 4            3               16   2.5    AZ           []  business
#
#                                                  url
# 0  https://www.yelp.com/biz/hot-bagels-and-deli-g...
# 1  https://www.yelp.com/biz/jersey-mikes-subs-gil...
# 2  https://www.yelp.com/biz/sauce-pizza-and-wine-...
# 3  https://www.yelp.com/biz/fuddruckers-phoenix-3...
# 4  https://www.yelp.com/biz/mcdonalds-scottsdale-...
#
# [5 rows x 42 columns]

# %%
len(restaurants_all)
# Out:
# 3327

# %%
len(restaurants_all[restaurants_all['is_closed'] == 1])/len(restaurants_all)
# Out:
# 0.23113916441238352

# %%
restaurants_all.to_pickle('./yelp_dataset_processed/yelp_df_all_final.pkl')

# %%
restaurants_all_merged.to_pickle('./yelp_dataset_processed/restaurants_df_all_merged.pkl')
restaurants_all_notmerged.to_pickle('./yelp_dataset_processed/restaurants_df_all_notmerged.pkl')
